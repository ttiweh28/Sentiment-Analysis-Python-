# %%
import pandas as pd

# %%
mylist = []
fh = open('bobi2019.csv', 'r',encoding = 'utf8')

for line in fh:
    mylist.append(line.strip().split(','))

# %%
my1 = [item[2] for item in mylist if len(item)>2]

# %%
my1
# Out:
# ['ARTICLE CONTENT',
#  ' Museveni tells Bobi Wine"',
#  '"\t\t\t\tJose Chameleone',
#  '"\t\t\t\t\t\t MP',
#  "\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1496656157133-0'); });\t\t.\t\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1496657157715-0'); });\t\t\t\t\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1518611800417-0'); });\t\t\t\t\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1518611800417-0'); });",
#  "\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1496656157133-0'); });\t\t.\t\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1496657157715-0'); });\t\t\t\t\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1518611800417-0'); });\t\t\t\t\t\t\tgoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1518611800417-0'); });",
#  '\t\t\t\tOpposition bigwig meet in Jinja',
# ...

# %%
data = pd.DataFrame(my1)

# %%
data.to_csv
# Out:
# <bound method DataFrame.to_csv of                                                     0
# 0                                     ARTICLE CONTENT
# 1                           Museveni tells Bobi Wine"
# 2                            "\t\t\t\tJose Chameleone
# 3                                    "\t\t\t\t\t\t MP
# 4   \t\t\tgoogletag.cmd.push(function() { googleta...
# 5   \t\t\tgoogletag.cmd.push(function() { googleta...
# 6             \t\t\t\tOpposition bigwig meet in Jinja
# 7   "Close friends say Thomas disappeared since Ma...
# 8                         co-accused appear in court"
# 9                      "What makes the NRM win? First
# 10  "\t\t\t\t\t\tBobi Wine after he was put into a...
# 11  \t\t\tgoogletag.cmd.push(function() { googleta...
# 12  "\t\t\t\t\t\tMusic promoter Andy Mukasa (left)...
# 13  "By declaring his decision to stand for president
# 14  "\t\t\t\t\t\tMoses Byaruhanga\t\t\t\t\tThose w...
# 15                       says Pastor Wilson Bugembe "
# ...

# %%
data.head(3)
# Out:
#                             0
# 0             ARTICLE CONTENT
# 1   Museveni tells Bobi Wine"
# 2    "\t\t\t\tJose Chameleone

# %%
data[0]
# Out:
# 0                                       ARTICLE CONTENT
# 1                             Museveni tells Bobi Wine"
# 2                              "\t\t\t\tJose Chameleone
# 3                                      "\t\t\t\t\t\t MP
# 4     \t\t\tgoogletag.cmd.push(function() { googleta...
# 5     \t\t\tgoogletag.cmd.push(function() { googleta...
# 6               \t\t\t\tOpposition bigwig meet in Jinja
# 7     "Close friends say Thomas disappeared since Ma...
# 8                           co-accused appear in court"
# 9                        "What makes the NRM win? First
# 10    "\t\t\t\t\t\tBobi Wine after he was put into a...
# 11    \t\t\tgoogletag.cmd.push(function() { googleta...
# 12    "\t\t\t\t\t\tMusic promoter Andy Mukasa (left)...
# 13    "By declaring his decision to stand for president
# 14    "\t\t\t\t\t\tMoses Byaruhanga\t\t\t\t\tThose w...
# 15                         says Pastor Wilson Bugembe "
# 16    "\t\t\t\t\t\tBobi Wine was on Monday placed in...
# ...

# %%
data[0][4]
# Out:
# ' }); . }); }); });'

# %%
# data=data.dropna(how='any')
data[0]=data[0].str.replace("(googletag\.cmd\.push\(.*?\);)"," ")
data[0]=data[0].str.replace("\s+", " ")
data[0]=data[0].str.replace("\-\-\>.*?\-\-\>", " ")
data
# Out:
#                                                     0
# 0                                     ARTICLE CONTENT
# 1                           Museveni tells Bobi Wine"
# 2                                   " Jose Chameleone
# 3                                                " MP
# 4                                   }); . }); }); });
# 5                                   }); . }); }); });
# 6                     Opposition bigwig meet in Jinja
# 7   "Close friends say Thomas disappeared since Ma...
# 8                         co-accused appear in court"
# 9                      "What makes the NRM win? First
# 10  " Bobi Wine after he was put into a Police van...
# 11                                  }); . }); }); });
# 12  " Music promoter Andy Mukasa (left) addressing...
# 13  "By declaring his decision to stand for president
# 14  " Moses Byaruhanga Those who say that Bobi Win...
# 15                       says Pastor Wilson Bugembe "
# ...

# %%
data[0][4]
# Out:
# ' }); . }); }); });'

# %%
data.to_csv('cleandata.csv')

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt

#convert list to string and generate
unique_string=''.join(map(str, my1))
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %%
my_list = []
fh = open('cleandata.csv', 'r')

for line in fh:
    my_list.append(line.strip().split(','))

# %%
my_list[2][1]
# Out:
# '" Museveni tells Bobi Wine"""'

# %%
my2 = [item[1] for item in my_list]

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt

#convert list to string and generate
unique_string=''.join(map(str, my2))
wordcloud = WordCloud(width = 1000, height = 500,background_color='white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("wordcloud_newvsion"+".png", bbox_inches='tight')
plt.show()
plt.close()
