# %%
import pandas as pd

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-00ff0b082a7d> in <module>()
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
import string
# text5="President Yoweri Museveni chats with female Police officers during the International Womenâ€™s Day at Kololo Independence Grounds on March 8, 2016. PPU photo By President Yoweri Kaguta MuseveniTuesday, March 8, 2016, was International Womenâ€™s Day.Â  In Uganda, it was commemorated at the Kololo Independence Grounds under the theme: â€œWomenâ€™s Economic Empowerment; A vehicle for Sustainable Developmentâ€. President Yoweri Museveni was the chief guest and below is his speechH. E. the Vice President;Rt. Hon Speaker of Parliament;His Lordship, the Chief Justice;Rt. Hon Prime Minister;Hon. Leader of the Opposition;Hon. Ministers;Hon Members of Parliament;Your Excellencies the Ambassadors and High Commissioners;Fellow Ugandans;Ladies and Gentlemen.I am pleased to welcome you all to the national celebrations to commemorate International Womenâ€™s Day 2016. Let me take this opportunity to congratulate all Ugandans upon the successful completion of the general elections and to thank all those who observed peace and conducted themselves in an orderly and lawful manner during this process.IÂ  wish to thank everyoneÂ  who has contributed to the renewal of my mandate and reinforcing your confidence in the National Resistance Movement Government to steer you to Ugandaâ€™s Vision 2040 focusing on unity,Â  "
#def remove_unicode(text):
   # text=''.join(x for x in text if x in string.printable)
    #return text
#mod_text=remove_unicode(text5)

# from textblob import TextBlob

def comp_sentiment(text):
    text=''.join(x for x in text if x in string.printable)
    return TextBlob(text).sentiment.polarity

print (comp_sentiment('why are you bad?'))
# Out:
# -0.7

# %%
data = pd.read_csv('kidnap.csv')
data
# Out:
#                                                DATES  \
# 0               Added 20th July 2019 09:33 PM
# 1               Added 5th March 2019 04:35 PM
# 2              Added 19th April 2019 01:05 PM
# 3               Added 25th July 2019 10:30 AM
# 4              Added 30th April 2019 04:04 PM
# 5              Added 29th April 2019 08:00 AM
# 6              Added 24th March 2019 06:30 PM
# 7           Added 12th February 2019 07:23 PM
# 8           Added 12th February 2019 08:01 PM
# 9                Added 27th May 2019 11:23 AM
# 10              Added 24th July 2019 05:04 PM
#
#                                         TITLE ARTICLE  \
# 0   Armed men kidnap two children in Kanungu, flee...
# 1         Kidnappers free Nigeria winger&#39;s mother
# 2         American tourist abduction: Suspect charged
# 3      Armed men kidnap two children, run to DR Congo
# 4                     Kidnaps: Police urges vigilance
# 5           Nigeria gunmen kidnap foreign oil workers
# 6          Businesswoman kidnapped, robbed in Kampala
# 7                       Police recover kidnapped baby
# 8                       Police recover kidnapped baby
# 9      Fraud, kidnap charges against Bakaleke dropped
# 10               Special Report: Murders that have...
#
#                                       ARTICLE CONTENT
# 0   Police say the two children were kidnapped on ...
# 1   \t\t\tgoogletag.cmd.push(function() { googleta...
# 2   Onesmus Byaruhanga alias Kaliisa, 43, was on T...
# 3   Police preliminary investigations show that th...
# 4   \t\t\t\t\t\tPolice spokesperson Fred Enanga ca...
# 5   \t\t\t\t\t\t Gas flare is seen at Shell Cawtha...
# 6   \t\t\tgoogletag.cmd.push(function() { googleta...
# 7   \t\t\tgoogletag.cmd.push(function() { googleta...
# 8   The Police tracked the culprits number 0782683...
# 9   \t\t\t\t\t\tASP Siraje Bakaleke's whereabouts ...
# 10  \t\t\tgoogletag.cmd.push(function() { googleta...

# %%
data['SENTIMENT']=data['TITLE ARTICLE'].apply(comp_sentiment)
data
# Out:
#                                                DATES  \
# 0               Added 20th July 2019 09:33 PM
# 1               Added 5th March 2019 04:35 PM
# 2              Added 19th April 2019 01:05 PM
# 3               Added 25th July 2019 10:30 AM
# 4              Added 30th April 2019 04:04 PM
# 5              Added 29th April 2019 08:00 AM
# 6              Added 24th March 2019 06:30 PM
# 7           Added 12th February 2019 07:23 PM
# 8           Added 12th February 2019 08:01 PM
# 9                Added 27th May 2019 11:23 AM
# 10              Added 24th July 2019 05:04 PM
#
#                                         TITLE ARTICLE  \
# 0   Armed men kidnap two children in Kanungu, flee...
# 1         Kidnappers free Nigeria winger&#39;s mother
# 2         American tourist abduction: Suspect charged
# 3      Armed men kidnap two children, run to DR Congo
# 4                     Kidnaps: Police urges vigilance
# 5           Nigeria gunmen kidnap foreign oil workers
# 6          Businesswoman kidnapped, robbed in Kampala
# 7                       Police recover kidnapped baby
# 8                       Police recover kidnapped baby
# 9      Fraud, kidnap charges against Bakaleke dropped
# 10               Special Report: Murders that have...
#
#                                       ARTICLE CONTENT  SENTIMENT
# 0   Police say the two children were kidnapped on ...   0.000000
# 1   \t\t\tgoogletag.cmd.push(function() { googleta...   0.400000
# 2   Onesmus Byaruhanga alias Kaliisa, 43, was on T...   0.000000
# 3   Police preliminary investigations show that th...   0.000000
# 4   \t\t\t\t\t\tPolice spokesperson Fred Enanga ca...   0.000000
# 5   \t\t\t\t\t\t Gas flare is seen at Shell Cawtha...  -0.125000
# 6   \t\t\tgoogletag.cmd.push(function() { googleta...   0.000000
# 7   \t\t\tgoogletag.cmd.push(function() { googleta...   0.000000
# 8   The Police tracked the culprits number 0782683...   0.000000
# 9   \t\t\t\t\t\tASP Siraje Bakaleke's whereabouts ...   0.000000
# 10  \t\t\tgoogletag.cmd.push(function() { googleta...   0.357143

# %%
import string
# text5="President Yoweri Museveni chats with female Police officers during the International Womenâ€™s Day at Kololo Independence Grounds on March 8, 2016. PPU photo By President Yoweri Kaguta MuseveniTuesday, March 8, 2016, was International Womenâ€™s Day.Â  In Uganda, it was commemorated at the Kololo Independence Grounds under the theme: â€œWomenâ€™s Economic Empowerment; A vehicle for Sustainable Developmentâ€. President Yoweri Museveni was the chief guest and below is his speechH. E. the Vice President;Rt. Hon Speaker of Parliament;His Lordship, the Chief Justice;Rt. Hon Prime Minister;Hon. Leader of the Opposition;Hon. Ministers;Hon Members of Parliament;Your Excellencies the Ambassadors and High Commissioners;Fellow Ugandans;Ladies and Gentlemen.I am pleased to welcome you all to the national celebrations to commemorate International Womenâ€™s Day 2016. Let me take this opportunity to congratulate all Ugandans upon the successful completion of the general elections and to thank all those who observed peace and conducted themselves in an orderly and lawful manner during this process.IÂ  wish to thank everyoneÂ  who has contributed to the renewal of my mandate and reinforcing your confidence in the National Resistance Movement Government to steer you to Ugandaâ€™s Vision 2040 focusing on unity,Â  "
def remove_unicode(text):
    text=''.join(x for x in text if x in string.printable)
    return text
mod_text=remove_unicode(text5)

from textblob import TextBlob

def comp_sentiment(text):
    text=''.join(x for x in text if x in string.printable)
    return TextBlob(text).sentiment.polarity

print (comp_sentiment('Today I went to Barbeque Nation  the Food was  awesome'))

text2="President Yoweri Museveni chats with female Police officers during the International Womenâ€™s "

print (comp_sentiment(text5))

fd2016['SENTIMENT']=fd2016['ARTICLE CONTENT'].apply(comp_sentiment)
fd2016.head(6)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-72f3830bc1b6> in <module>()
#       6 mod_text=remove_unicode(text5)
#       7
# ----> 8 from textblob import TextBlob
#       9 def comp_sentiment(text):
#      10     text=''.join(x for x in text if x in string.printable)
#
# ImportError: No module named textblob
