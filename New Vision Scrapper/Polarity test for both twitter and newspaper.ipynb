# %%
import pandas as pd

# %%
from textblob import TextBlob

# %%
import string
# text5="President Yoweri Museveni chats with female Police officers during the International Womenâ€™s Day at Kololo Independence Grounds on March 8, 2016. PPU photo By President Yoweri Kaguta MuseveniTuesday, March 8, 2016, was International Womenâ€™s Day.Â  In Uganda, it was commemorated at the Kololo Independence Grounds under the theme: â€œWomenâ€™s Economic Empowerment; A vehicle for Sustainable Developmentâ€. President Yoweri Museveni was the chief guest and below is his speechH. E. the Vice President;Rt. Hon Speaker of Parliament;His Lordship, the Chief Justice;Rt. Hon Prime Minister;Hon. Leader of the Opposition;Hon. Ministers;Hon Members of Parliament;Your Excellencies the Ambassadors and High Commissioners;Fellow Ugandans;Ladies and Gentlemen.I am pleased to welcome you all to the national celebrations to commemorate International Womenâ€™s Day 2016. Let me take this opportunity to congratulate all Ugandans upon the successful completion of the general elections and to thank all those who observed peace and conducted themselves in an orderly and lawful manner during this process.IÂ  wish to thank everyoneÂ  who has contributed to the renewal of my mandate and reinforcing your confidence in the National Resistance Movement Government to steer you to Ugandaâ€™s Vision 2040 focusing on unity,Â  "
#def remove_unicode(text):
   # text=''.join(x for x in text if x in string.printable)
    #return text
#mod_text=remove_unicode(text5)

# from textblob import TextBlob

def comp_sentiment(text):
    text=''.join(x for x in text if x in string.printable)
    return TextBlob(text).sentiment.polarity

print (comp_sentiment('why are you bad?'))
# Out:
# -0.7

# %%
data = pd.read_csv('bobiwine.csv')

# %%
data['SENTIMENT']=data['TITLE ARTICLE'].apply(comp_sentiment)
type(data)
data.to_csv('newvision_polar.csv',index=False)

# %% [markdown]
# Polarity for twitter

# %%
data_twitter = pd.read_csv('Bobi_tw.csv')
data_twitter
# Out:
#                      DATES                                    SENDER  \
# 0             [\nJul 21\n]                           Financial Times
# 1             [\nJul 24\n]                           AFP news agency
# 2             [\nJul 27\n]                                 BOBI WINE
# 3             [\nJul 25\n]            Maamaafrica Stephie Kisha 🇺🇬
# 4             [\nJul 24\n]                           BBC News Africa
# 5             [\nJul 24\n]                                 Arab News
# 6             [\nJul 27\n]                                 BOBI WINE
# 7             [\nJul 24\n]                              Daily Nation
# 8             [\nJul 24\n]                           Al Jazeera News
# 9             [\nJul 24\n]                           AFP news agency
# 10            [\nJul 24\n]                          BBC News (World)
# 11            [\nJul 24\n]       UGANDA CHANNEL#PEOPLEPOWER_OURPOWER
# 12            [\nJul 24\n]                             Sonia Wa Bobi
# 13            [\nJul 24\n]                              Joyce Bagala
# 14            [\nJul 24\n]                        MUNASSINGO WA BOBI
# 15            [\nJul 24\n]                         The Star Breaking
# 16            [\nJul 24\n]                          Citizen TV Kenya
# 17            [\nJul 24\n]                          NZE_NSEKANABASSI
# 18            [\nJul 24\n]                              Moseax  🇰🇪
# 19            [\nJul 24\n]                                   EKYOOTO
# 20            [\nJul 24\n]                        Al Jazeera English
# 21            [\nJul 24\n]                            #CanaryReports
# 22            [\nJul 24\n]                          HON JEREMY MBABU
# 23            [\nJul 24\n]                                 NTV Kenya
# 24            [\nJul 21\n]                    Ssesangaismael Freeman
# 25            [\nJul 24\n]                           BBC News Africa
# 26            [\nJul 22\n]                           Kiggundu Martin
# 27            [\nJul 22\n]                             Yassin Mwanje
# 28   [\n20h20 hours ago\n]                          Next Door Muslim
# 29            [\nJul 24\n]                             Jeffrey Smith
# ..                     ...                                       ...
# 445           [\nJan 10\n]                                NTV UGANDA
# 446            [\nJan 8\n]                              The Observer
# 447            [\nJan 7\n]                            MrHashTag 🇺🇬
# 448            [\nJan 7\n]                            Samwise Gamgee
# 449            [\nJan 7\n]                                 ands JEFF
# 450            [\nJan 7\n]                           Grace Natabaalo
# 451            [\nJan 7\n]  King Of East Africa  🇰🇪 🇺🇬 🇹🇿 🇷🇼
# 452            [\nJan 6\n]                       sotrixbax 🇺🇬 🇺🇬
# 453            [\nJan 6\n]                        A Pass Bagonza  🐐
# 454            [\nJan 3\n]                                 ands JEFF
# 455            [\nJan 3\n]                            NBS Television
# 456            [\nJan 3\n]                             CECILE.  🇺🇬
# 457            [\nJan 3\n]                                ✨Mrs 007 ✨
# 458            [\nJan 3\n]                            NBS Television
# 459            [\nJan 3\n]                            Anne Whitehead
# 460            [\nJan 3\n]                               Wyclif 🇺🇬
# 461            [\nJan 3\n]                              iam_maggimbi
# 462            [\nJan 3\n]                        Jeremiah Ainebyona
# 463            [\nJan 3\n]                              Aine Derrick
# 464            [\nJan 3\n]                              Aine Derrick
# 465            [\nJan 2\n]                              Richie™ 🇺🇬
# 466            [\nJan 2\n]                         yo momma's fav 😈
# 467            [\nJan 2\n]                        Sama And TheLights
# 468            [\nJan 1\n]                             Katende Erick
# 469            [\nJan 1\n]                                Sir Arthur
# 470            [\nJan 1\n]                             Moses Rudende
# 471            [\nJan 1\n]                           Kaya Jbuk 🌿 🏉
# 472            [\nJan 1\n]                                africanews
# 473            [\nJan 1\n]                                africanews
# 474           [\nDec 31\n]                        David Kezio-Musoke
#
#                                        ARTICLE CONTENT
# 0    [Bobi Wine takes on Uganda's ageing dictator h...
# 1    [VIDEO:  Ugandan pop star turned leading oppos...
# 2    [Uganda Mathematics Society (UMS) celebrated t...
# 3    [Always remember that this country is bigger t...
# 4    [What are the most pressing issues right now i...
# 5    [Singer turned politician Robert Kyagulanyi, a...
# 6    [Thank you 'first lady' for representing the f...
# 7    [Uganda's popstar MP Bobi Wine to contest 2021...
# 8    [Bobi Wine formally declares presidential bid ...
# 9    [#BREAKING Ugandan pop star MP Bobi Wine annou...
# 10   [Ugandan pop star Bobi Wine to run against Yow...
# 11   [#BobiWine thank you to be the voice of very m...
# 12   [I will lead the struggle and never betray the...
# 13   [Kyadondo East lawmaker Robert Kyagulanyi Ssen...
# 14   [Words of my president H.E Bobi Wine\n\n"I loo...
# 15   [UGANDAN pop star and opposition MP Bobi Wine ...
# 16   [Bobi Wine officially declares bid to challeng...
# 17   [Kyadondo East member of Parliament and #Peopl...
# 18   [Bobi Wine's problems are about to Explode!\nA...
# 19   [Bobi wine confirms he is ready to challenge M...
# 20   [Pop star-turned-opposition leader, Bobi Wine,...
# 21   [People Power say they won\u2019t mention hote...
# 22   [Bobi Wine ,a man with a vision for my generat...
# 23   ['On behalf of the people of Uganda I am chall...
# 24   [This is the reason why I like you #bobi wine ...
# 25   [Ugandan pop star Bobi Wine to run against Yow...
# 26   [Ssebo Mr President @Robert_Kyagulanyi @Ssenta...
# 27   [I call him Mr President\n#2021_is_our_year\n#...
# 28   [A church in Rukungiri invited and hosted the ...
# 29   [\u201cPresident Museveni and his praise singe...
# ..                                                 ...
# 445  [Bobi Wine named among top 100 global thinkers...
# 446  [#PeoplePower footprint in Sembabule worries N...
# 447  [Naye abanaUganda nokwetuminkiriza. So we were...
# 448  ["Army Generals should know that we are not at...
# 449  [Museveni paid music promoters UGX1,000,000,00...
# 450  [Sad to see a young man who is fearless when i...
# 451  [What makes Pastor Serwadda think he is more e...
# 452  [You can like Bobi wine without abusing Bebe c...
# 453  [Bobi wine Baby Cool hug and hand shake to me ...
# 454  [Bebecool: Bobi Wine is not an MP,  but Kyagul...
# 455  [BebeCool: How can I coexist with Bobi Wine wh...
# 456  [#NBSFrontline \nBebecool: Bobi wine is Musici...
# 457  [From the tweets on tl I can tell Bebe Cool is...
# 458  [Hon. Salaamu Musumba: If your issues with Bob...
# 459  [I fail to understand how Bobi Wine is suppose...
# 460  [So Bebe cool up to now still thinks that it's...
# 461  [Bebe cool:am talking about Bobi Wine not Kagu...
# 462  [Politics aside,  Imagine being 40plus and you...
# 463  [Musicians that rallied behind M7 in tubonga n...
# 464  [Whoever took this pic has a better cam than w...
# 465  [But truth to be told I haven't seen any Bobi ...
# 466  [Just in need of some information here!\nHow o...
# 467  [So here's a fun fact, Bebe Cool's Wasibukawa ...
# 468  [Now Ugandans are becoming a problem. You can'...
# 469  [From the look of things now even if Bobi Wine...
# 470  [I saw a tweet earlier saying Bobi Wine lives ...
# 471  [Bobi wine should start having concerts in the...
# 472  [Bobi Wine promises Ugandans 'the victor's cro...
# 473  [Uganda's Bobi Wine is 2018 Africanews Persona...
# 474  [So I wake up on 1st January 2019 to find that...
#
# [475 rows x 3 columns]

# %%
data_twitter['SENTIMENT']=data_twitter['ARTICLE CONTENT'].apply(comp_sentiment)
data_twitter.to_csv('data_twit.csv',index=False)
